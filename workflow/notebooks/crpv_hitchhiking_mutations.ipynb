# %% [markdown]
# Hitchhiking mutations refer to genetic variations that become more prevalent in a population due to their close physical linkage to a specific beneficial mutation. In essence, these mutations "hitch a ride" with the advantageous mutation during the process of natural selection, leading to their increased frequency in the population over time.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np 
import matplotlib.pylab as plt

# %%
fname = "crpv.cooccurring_mutations.csv"
df = pd.read_csv(fname)
df['mutation'] = df['ref'] + df['position'].astype(str).str.split(".0").str[0] + df['var'] 

df = df[['haplotype_id', 'start',
       'position', 'ref', 'var', 'reads', 'support', 'coverage', 'passage', 'file', 'mutation']]

# %%
mutations_of_interest = ['G1323A', 'G1363A']

df = df[df['mutation'].isin(mutations_of_interest)]

# only in sample K-10-a it looks like it could be hitch hiker mutations
df = df[df['passage'].isin(["K_p10_a", "K_p5_a", "K_p3_a", "K_p2_a", "K_p1_a"])]

# %%
# check which window is even covering both of them
# window 1315-1368: both
# window 1333-1386: only 1363
# window 1351-1404: only 1363
# window 1297-1350: only 1323
# window 1279-1332: only 1323
# window 1279-1332: only 1323 

df['haplotype_id'].unique()
# Out:
# array(['haplotype0-1315-1368', 'haplotype0-1333-1386',
#        'haplotype0-1297-1350', 'haplotype2-1279-1332',
#        'haplotype2-1315-1368', 'haplotype3-1315-1368',
#        'haplotype5-1315-1368', 'haplotype1-1333-1386',
#        'haplotype2-1333-1386', 'haplotype6-1333-1386',
#        'haplotype0-1351-1404', 'haplotype2-1351-1404',
#        'haplotype3-1351-1404', 'haplotype5-1351-1404',
#        'haplotype2-1297-1350', 'haplotype1-1315-1368',
#        'haplotype4-1315-1368', 'haplotype6-1315-1368',
#        'haplotype3-1333-1386', 'haplotype5-1333-1386',
#        'haplotype7-1333-1386', 'haplotype1-1351-1404',
#        'haplotype4-1351-1404', 'haplotype1-1297-1350',
#        'haplotype0-1279-1332', 'haplotype1-1279-1332',
#        'haplotype4-1279-1332', 'haplotype5-1279-1332',
#        'haplotype6-1279-1332'], dtype=object)

# %%
# filter for start position such that both mutations are covered
df = df[df['start']==1315]

# %%
df.sort_values(['passage', 'haplotype_id'])[['passage', 
                                             'haplotype_id', 
                                             'mutation', 
                                             'reads', 
                                             'coverage', 
                                             'support']].head(50)
# Out:
#        passage          haplotype_id mutation   reads  coverage   support
# 53721  K_p10_a  haplotype0-1315-1368   G1323A     1.0    4803.0  0.699822
# 53724  K_p10_a  haplotype1-1315-1368   G1323A     3.0    4803.0  0.999885
# 53726  K_p10_a  haplotype1-1315-1368   G1363A     3.0    4803.0  0.999885
# 53727  K_p10_a  haplotype2-1315-1368   G1323A  4756.0    4803.0  1.000000
# 53728  K_p10_a  haplotype2-1315-1368   G1363A  4756.0    4803.0  1.000000
# 53729  K_p10_a  haplotype3-1315-1368   G1323A     2.0    4803.0  0.829556
# 53731  K_p10_a  haplotype3-1315-1368   G1363A     2.0    4803.0  0.829556
# 53732  K_p10_a  haplotype4-1315-1368   G1323A     5.0    4803.0  1.000000
# 53734  K_p10_a  haplotype4-1315-1368   G1363A     5.0    4803.0  1.000000
# 53735  K_p10_a  haplotype5-1315-1368   G1323A    26.0    4803.0  1.000000
# 53737  K_p10_a  haplotype5-1315-1368   G1363A    26.0    4803.0  1.000000
# 53738  K_p10_a  haplotype6-1315-1368   G1363A    10.0    4803.0  1.000000
# 23841   K_p2_a  haplotype0-1315-1368   G1323A     4.0   10792.0  0.977670
# 40789   K_p3_a  haplotype0-1315-1368   G1323A    84.0   11810.0  1.000000
# 47006   K_p5_a  haplotype0-1315-1368   G1323A     1.0    5514.0  0.960575
# 47008   K_p5_a  haplotype2-1315-1368   G1323A  2101.0    5514.0  1.000000
# 47009   K_p5_a  haplotype2-1315-1368   G1363A  2101.0    5514.0  1.000000
# 47010   K_p5_a  haplotype3-1315-1368   G1323A   183.0    5514.0  1.000000
# 47012   K_p5_a  haplotype5-1315-1368   G1363A   217.0    5514.0  1.000000

# %% [markdown]
# ## get extra info about those mutations

# %%
df_anno = pd.read_csv("all_mutations.annotated.filtered.csv")

# %%
df_anno['mutation'] = df_anno['REF'] + df_anno['POS'].astype(str)+ df_anno['ALT']

# %%
df_anno = df_anno[df_anno['mutation'].isin(mutations_of_interest)]

# %%
df_anno = df_anno[['RefCodon', 'AltCodon', 'RefAminoAcid',
       'AltAminoAcid', 'CodonPosition', 'SNPCodonPosition', 'AminoAcidChange',
       'IsSynonymous', 'Product', 'ProteinID', 'VariantType', 'FeatureType',
        'mutation']]

# %%
df_anno
# Out:
#       RefCodon AltCodon RefAminoAcid AltAminoAcid CodonPosition  \
# 21392      CAG      CAA            Q            Q           205
# 21394      GAT      AAT            D            N           219
# 23487      GAT      AAT            D            N           219
# 24255      CAG      CAA            Q            Q           205
# 24258      GAT      AAT            D            N           219
# 25035      CAG      CAA            Q            Q           205
# 25038      GAT      AAT            D            N           219
# 25763      CAG      CAA            Q            Q           205
# 25766      GAT      AAT            D            N           219
# 25978      CAG      CAA            Q            Q           205
# 25982      GAT      AAT            D            N           219
# 26228      GAT      AAT            D            N           219
# 26833      CAG      CAA            Q            Q           205
# 27430      GAT      AAT            D            N           219
# 27771      GAT      AAT            D            N           219
# 28043      GAT      AAT            D            N           219
# 28282      GAT      AAT            D            N           219
# 29443      GAT      AAT            D            N           219
# 30046      GAT      AAT            D            N           219
# 30648      GAT      AAT            D            N           219
#
#       SNPCodonPosition AminoAcidChange  IsSynonymous  \
# 21392                2           Q205Q             1
# 21394                0           D219N             0
# 23487                0           D219N             0
# 24255                2           Q205Q             1
# 24258                0           D219N             0
# 25035                2           Q205Q             1
# 25038                0           D219N             0
# 25763                2           Q205Q             1
# 25766                0           D219N             0
# 25978                2           Q205Q             1
# 25982                0           D219N             0
# 26228                0           D219N             0
# 26833                2           Q205Q             1
# 27430                0           D219N             0
# 27771                0           D219N             0
# 28043                0           D219N             0
# 28282                0           D219N             0
# 29443                0           D219N             0
# 30046                0           D219N             0
# 30648                0           D219N             0
#
#                                Product    ProteinID VariantType FeatureType  \
# 21392  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 21394  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 23487  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 24255  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 24258  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 25035  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 25038  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 25763  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 25766  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 25978  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 25982  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 26228  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 26833  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 27430  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 27771  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 28043  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 28282  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 29443  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 30046  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
# 30648  nonstructural[space]polyprotein  NP_647481.1         SNP         CDS
#
#       mutation
# 21392   G1323A
# 21394   G1363A
# 23487   G1363A
# 24255   G1323A
# 24258   G1363A
# 25035   G1323A
# 25038   G1363A
# 25763   G1323A
# 25766   G1363A
# 25978   G1323A
# 25982   G1363A
# 26228   G1363A
# 26833   G1323A
# 27430   G1363A
# 27771   G1363A
# 28043   G1363A
# 28282   G1363A
# 29443   G1363A
# 30046   G1363A
# 30648   G1363A
